# %% [markdown]
# # Registrador
#
# Um registrador é um dispositivo de armazenamento que consiste em flip-flops em sequência para guardar sequências de bits. Além do armazenamento de dados, registradores também podem servir para o deslocamento de dados.
